# %%
import os
import importlib
import logging

# Step 1: Import the modules explicitly
import process_single

# Step 2: Reload the modules
importlib.reload(process_single)

# Step 3: Re-import the functions/classes
from process_single import *

# %%
# 'close' - Default, uses closing price only
# 'formula1' - (open+close+3*(high+low))/8
# 'formula2' - close+high+low-2*open
# 'formula3' - (close+5*(high+low)-7*(open))/4
# 'formula4' - (open+close+5*(high+low))/12
# 'conditional1' - (close > open ? high : low)
# 'conditional2' - (ohlc4 > h_open ? high : low)

# Define technical indicators to calculate
ta_indicators = [
    # {'name': 'SG', 'periods': [9, 11, 14, 26, 52], 'implementation': 'rolling', 'poly_order' : 5},
    {'name': 'SG', 'periods': [9, 11, 15, 27, 53], 'implementation': 'rolling', 'poly_order' : 2},
    {'name': 'KDJ', 'periods': [9]},  # periods don't matter for KDJ
    {'name': 'WILLIAMS_R', 'periods': [14]},
    {'name': 'STOCH_RSI', 'periods': [14, 26, 40]},
    {'name': 'RSI', 'periods': [7, 14, 21, 40]},
    {'name': 'RVSI', 'periods': [9, 14, 26, 52], 'mode': 'obv', 'price_source': 'conditional1'},
    {'name': 'MACD', 'periods': [0]},  # periods doesn't matter, uses default values
    {'name': 'CCI', 'periods': [20, 40]},
    {'name': 'AO', 'periods': []},                  # No periods needed
    {'name': 'APO', 'periods': [12, 26]},           # Fast and slow periods
    {'name': 'MOM', 'periods': [10, 14, 40]},           # Standard periods
    {'name': 'TSI', 'periods': [25]},               # Long period
    {'name': 'CMO', 'periods': [14, 20, 40]},            # Standard periods
    {'name': 'VOLATILITY_INDEX', 'periods': [7, 14, 26, 52]},
    {'name': 'EDMA', 'price_source':'conditional1', 'periods': [9, 14, 20, 40, 100, 200]},
    {'name': 'SMA', 'price_source':'conditional1', 'periods': [9, 14, 20, 50, 100, 200]},
    {'name': 'HMA', 'price_source':'conditional1', 'periods': [5, 9, 14, 20, 50, 100, 200]},
    {'name': 'DEMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'LSMA', 'price_source':'conditional1', 'periods': [5,9,14,20, 50]},
    {'name': 'EMA', 'price_source':'conditional1', 'periods': [9, 14, 20, 40, 100, 200]},
    {'name': 'RMA', 'price_source':'conditional1', 'periods': [14, 20]},
    {'name': 'SMMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'TEMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'THMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'VWMA', 'price_source':'conditional1', 'periods': [9, 14, 20, 50, 100]},
    {'name': 'WMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'ZEMA', 'price_source':'conditional1', 'periods': [9, 14, 20, 26, 52]},
    {'name': 'EVWMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'T3', 'price_source':'conditional1', 'periods': [3,5,20]},
    {'name': 'WWMA', 'price_source':'conditional1', 'periods': [14, 20]},
    {'name': 'CMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'GMMA', 'price_source':'conditional1', 'periods': [20, 50]},
    {'name': 'EALF', 'price_source':'conditional1', 'periods': [9, 12, 20, 26, 50]},
    {'name': 'ELF', 'price_source':'conditional1', 'periods': [20,50]},
    {'name': 'SWMA', 'price_source':'conditional1', 'periods': [20, 50]},
    # {'name': 'MAMA', 'price_source':'conditional1', 'periods': [20,50]},
    # {'name': 'FAMA', 'price_source':'conditional1', 'periods': [20,50]}
    ]

ta_indicators2 = [{'name': 'volume'},
    {'name': 'KDJ', 'periods': [9]},
    {'name': 'MACD', 'periods': [0]},
    {'name': 'CCI', 'periods': [20, 40]},
    {'name': 'VOLATILITY_INDEX', 'periods': [14]},
    {'name': 'WILLIAMS_R', 'periods': [14]},
    {'name': 'STOCH_RSI', 'periods': [14, 40]},
    {'name': 'RSI', 'periods': [14, 21, 40]},
    {'name': 'AO', 'periods': []}, 
    {'name': 'APO', 'periods': [12, 26]},  
    {'name': 'TSI', 'periods': [25]}, 
    {'name': 'CMO', 'periods': [14, 20, 40]}, 
    {'name': 'MOM', 'periods': [14, 40]},
    ]

timeframe = '15m'
symbol='SOL'

# Create processor for a crypto data file
processor = CryptoTAProcessor(
    csv_filename=f'crypto_data/{symbol}USDT_{timeframe}_complete_history.csv',
    ta_indicators=ta_indicators,
    output_dir='crypto_data/',
    output_filename=f'{symbol}_{timeframe}_2025.csv',  # Custom output filename
    # start_date='2023-01-01'  # 'YYYY-MM-DD', 
    verbose=True
)

# Process and save the data
result_df = processor.process_and_save()
# Out:
# 2025-08-07 03:55:05,252 - INFO - Initializing CryptoTAProcessor for file: F:/CMAPSS/TFT/crypto_data/SOLUSDT_1m_complete_history.csv
# 2025-08-07 03:55:05,253 - INFO - Output directory: F:/CMAPSS/TFT/prepared_data/
# 2025-08-07 03:55:05,254 - INFO - Custom output filename: SOL_1m_2024.csv
# 2025-08-07 03:55:05,254 - INFO - Start date filter: None (processing all data)
# 2025-08-07 03:55:05,254 - INFO - Default price source for indicators: close
# 2025-08-07 03:55:05,255 - INFO - Technical indicators to calculate: SG(5 periods, src=close), KDJ(1 periods, src=close), WILLIAMS_R(1 periods, src=close), STOCH_RSI(3 periods, src=close), RSI(4 periods, src=close), RVSI(4 periods, src=conditional1), MACD(1 periods, src=close), CCI(2 periods, src=close), AO(0 periods, src=close), APO(2 periods, src=close), MOM(3 periods, src=close), TSI(1 periods, src=close), CMO(3 periods, src=close), VOLATILITY_INDEX(4 periods, src=close), EDMA(6 periods, src=conditional1), SMA(6 periods, src=conditional1), HMA(7 periods, src=conditional1), DEMA(2 periods, src=conditional1), LSMA(5 periods, src=conditional1), EMA(6 periods, src=conditional1), RMA(2 periods, src=conditional1), SMMA(2 periods, src=conditional1), TEMA(2 periods, src=conditional1), THMA(2 periods, src=conditional1), VWMA(5 periods, src=conditional1), WMA(2 periods, src=conditional1), ZEMA(5 periods, src=conditional1), EVWMA(2 periods, src=conditional1), T3(3 periods, src=conditional1), WWMA(2 periods, src=conditional1), CMA(2 periods, src=conditional1), GMMA(2 periods, src=conditional1), EALF(5 periods, src=conditional1), ELF(2 periods, src=conditional1), SWMA(2 periods, src=conditional1)
# 2025-08-07 03:55:05,256 - INFO - Ensured output directory exists: F:/CMAPSS/TFT/prepared_data/
# 2025-08-07 03:55:05,257 - INFO - ==== Starting processing of F:/CMAPSS/TFT/crypto_data/SOLUSDT_1m_complete_history.csv ====
# Loading data:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-07 03:55:05,269 - INFO - Loading data from: F:/CMAPSS/TFT/crypto_data/SOLUSDT_1m_complete_history.csv
# 2025-08-07 03:55:05,269 - INFO - Reading CSV file...
# 2025-08-07 03:55:06,541 - INFO - CSV loaded with 840876 rows and 12 columns
# 2025-08-07 03:55:06,542 - INFO - Using 'timestamp' as timestamp column
# 2025-08-07 03:55:06,543 - INFO - Converting timestamp column to datetime...
# 2025-08-07 03:55:07,061 - INFO - Timestamp column converted to datetime
# 2025-08-07 03:55:07,062 - INFO - Set 'timestamp' as DataFrame index
# 2025-08-07 03:55:07,063 - INFO - Identifying OHLCV columns...
# 2025-08-07 03:55:07,064 - INFO - Extracting and standardizing OHLCV columns...
# 2025-08-07 03:55:07,067 - INFO - Mapped 'open' to standardized 'open'
# 2025-08-07 03:55:07,069 - INFO - Mapped 'high' to standardized 'high'
# 2025-08-07 03:55:07,072 - INFO - Mapped 'low' to standardized 'low'
# 2025-08-07 03:55:07,075 - INFO - Mapped 'close' to standardized 'close'
# 2025-08-07 03:55:07,077 - INFO - Mapped 'volume' to standardized 'volume'
# 2025-08-07 03:55:07,078 - INFO - Data loading completed in 1.81 seconds
# 2025-08-07 03:55:07,079 - INFO - Final dataframe shape: (840876, 5)
# 2025-08-07 03:55:07,085 - INFO - Starting technical indicator calculations...
# Calculating indicators:   0%|          | 0/107 [00:00<?, ?it/s]
# 2025-08-07 03:55:07,094 - INFO - Calculating price data using source: close
# 2025-08-07 03:55:07,095 - INFO - Using close price
# 2025-08-07 03:55:07,096 - INFO - Calculating Savitzky-Golay filter with window lengths [9, 11, 15, 27, 53] using price source: close...
# 2025-08-07 03:55:07,096 - INFO - Using polynomial order: 2
# 2025-08-07 03:55:07,097 - INFO - Using SG filter implementation: rolling
# 2025-08-07 03:55:07,746 - INFO - Savitzky-Golay filter with window=9, poly_order=2, implementation=rolling completed
# 2025-08-07 03:55:08,513 - INFO - Savitzky-Golay filter with window=11, poly_order=2, implementation=rolling completed
# 2025-08-07 03:55:09,485 - INFO - Savitzky-Golay filter with window=15, poly_order=2, implementation=rolling completed
# 2025-08-07 03:55:11,217 - INFO - Savitzky-Golay filter with window=27, poly_order=2, implementation=rolling completed
# 2025-08-07 03:55:14,650 - INFO - Savitzky-Golay filter with window=53, poly_order=2, implementation=rolling completed
# 2025-08-07 03:55:14,652 - INFO - Calculating KDJ indicator using price source: close...
# 2025-08-07 03:55:14,819 - INFO - KDJ indicator calculation completed
# 2025-08-07 03:55:14,820 - INFO - Calculating Williams %R with periods [14] using price source: close...
# 2025-08-07 03:55:14,860 - INFO - Williams %R_14 calculation completed
# 2025-08-07 03:55:14,861 - INFO - Calculating Stochastic RSI with periods [14, 26, 40] using price source: close...
# 2025-08-07 03:55:16,132 - INFO - Stochastic RSI_14 calculation completed
# 2025-08-07 03:55:16,579 - INFO - Stochastic RSI_26 calculation completed
# 2025-08-07 03:55:17,035 - INFO - Stochastic RSI_40 calculation completed
# 2025-08-07 03:55:17,036 - INFO - Calculating RSI with periods [7, 14, 21, 40] using price source: close...
# 2025-08-07 03:55:17,267 - INFO - RSI_7 calculation completed
# 2025-08-07 03:55:17,502 - INFO - RSI_14 calculation completed
# 2025-08-07 03:55:17,735 - INFO - RSI_21 calculation completed
# 2025-08-07 03:55:17,964 - INFO - RSI_40 calculation completed
# 2025-08-07 03:55:17,965 - INFO - Calculating price data using source: conditional1
# 2025-08-07 03:55:17,966 - INFO - Using conditional: (close > open ? high : low)
# 2025-08-07 03:55:33,543 - INFO - Calculating RVSI indicator with periods [9, 14, 26, 52] using price source: conditional1...
# 2025-08-07 03:55:33,544 - INFO - Using RVSI mode: obv
# 2025-08-07 03:55:34,011 - INFO - RVSI_9 calculation completed
# 2025-08-07 03:55:34,478 - INFO - RVSI_14 calculation completed
# 2025-08-07 03:55:34,963 - INFO - RVSI_26 calculation completed
# 2025-08-07 03:55:35,596 - INFO - RVSI_52 calculation completed
# 2025-08-07 03:55:35,597 - INFO - Calculating MACD indicator using price source: close...
# 2025-08-07 03:55:35,660 - INFO - MACD indicator calculation completed
# 2025-08-07 03:55:35,661 - INFO - Calculating CCI with periods [20, 40] using price source: close...
# 2025-08-07 03:55:35,715 - INFO - CCI_20 calculation completed
# 2025-08-07 03:55:35,800 - INFO - CCI_40 calculation completed
# 2025-08-07 03:55:35,800 - INFO - Calculating Awesome Oscillator using high/low data...
# 2025-08-07 03:55:36,101 - INFO - Awesome Oscillator calculation completed
# 2025-08-07 03:55:36,102 - INFO - Calculating Absolute Price Oscillator...
# 2025-08-07 03:55:36,733 - INFO - APO with fast=12, slow=26 calculation completed
# 2025-08-07 03:55:36,734 - INFO - Calculating MOM with periods [10, 14, 40] using price source: close...
# 2025-08-07 03:55:36,744 - INFO - MOM_10 calculation completed
# 2025-08-07 03:55:36,754 - INFO - MOM_14 calculation completed
# 2025-08-07 03:55:36,764 - INFO - MOM_40 calculation completed
# 2025-08-07 03:55:36,765 - INFO - Calculating True Strength Index with periods [25]...
# 2025-08-07 03:55:37,093 - INFO - TSI_25 calculation completed
# 2025-08-07 03:55:37,094 - INFO - Calculating CMO with periods [14, 20, 40] using price source: close...
# 2025-08-07 03:55:37,156 - INFO - CMO_14 calculation completed
# 2025-08-07 03:55:37,181 - INFO - CMO_20 calculation completed
# 2025-08-07 03:55:37,212 - INFO - CMO_40 calculation completed
# 2025-08-07 03:55:37,213 - INFO - Calculating VOLATILITY_INDEX with periods [7, 14, 26, 52] using price source: close...
# 2025-08-07 03:55:37,401 - INFO - VOLATILITY_INDEX_7 calculation completed
# 2025-08-07 03:55:37,619 - INFO - VOLATILITY_INDEX_14 calculation completed
# 2025-08-07 03:55:37,825 - INFO - VOLATILITY_INDEX_26 calculation completed
# 2025-08-07 03:55:38,096 - INFO - VOLATILITY_INDEX_52 calculation completed
# 2025-08-07 03:55:38,098 - INFO - Calculating EDMA with periods [9, 14, 20, 40, 100, 200] using price source: conditional1...
# 2025-08-07 03:55:39,641 - INFO - EDMA_9 calculation completed
# 2025-08-07 03:55:40,039 - INFO - EDMA_14 calculation completed
# 2025-08-07 03:55:40,446 - INFO - EDMA_20 calculation completed
# 2025-08-07 03:55:40,896 - INFO - EDMA_40 calculation completed
# 2025-08-07 03:55:41,463 - INFO - EDMA_100 calculation completed
# 2025-08-07 03:55:42,259 - INFO - EDMA_200 calculation completed
# 2025-08-07 03:55:42,260 - INFO - Calculating SMA with periods [9, 14, 20, 50, 100, 200] using price source: conditional1...
# 2025-08-07 03:55:42,379 - INFO - SMA_9 calculation completed
# 2025-08-07 03:55:42,504 - INFO - SMA_14 calculation completed
# 2025-08-07 03:55:42,631 - INFO - SMA_20 calculation completed
# 2025-08-07 03:55:42,794 - INFO - SMA_50 calculation completed
# 2025-08-07 03:55:43,060 - INFO - SMA_100 calculation completed
# 2025-08-07 03:55:43,621 - INFO - SMA_200 calculation completed
# 2025-08-07 03:55:43,623 - INFO - Calculating HMA with periods [5, 9, 14, 20, 50, 100, 200] using price source: conditional1...
# 2025-08-07 03:55:43,678 - INFO - HMA_5 calculation completed
# 2025-08-07 03:55:43,742 - INFO - HMA_9 calculation completed
# 2025-08-07 03:55:43,829 - INFO - HMA_14 calculation completed
# 2025-08-07 03:55:43,922 - INFO - HMA_20 calculation completed
# 2025-08-07 03:55:44,093 - INFO - HMA_50 calculation completed
# 2025-08-07 03:55:44,426 - INFO - HMA_100 calculation completed
# 2025-08-07 03:55:45,426 - INFO - HMA_200 calculation completed
# 2025-08-07 03:55:45,428 - INFO - Calculating DEMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:55:45,456 - INFO - DEMA_20 calculation completed
# 2025-08-07 03:55:45,483 - INFO - DEMA_50 calculation completed
# 2025-08-07 03:55:45,483 - INFO - Calculating LSMA with periods [5, 9, 14, 20, 50] using price source: conditional1...
# 2025-08-07 03:55:45,678 - INFO - LSMA_5 calculation completed
# 2025-08-07 03:55:45,812 - INFO - LSMA_9 calculation completed
# 2025-08-07 03:55:45,951 - INFO - LSMA_14 calculation completed
# 2025-08-07 03:55:46,079 - INFO - LSMA_20 calculation completed
# 2025-08-07 03:55:46,251 - INFO - LSMA_50 calculation completed
# 2025-08-07 03:55:46,252 - INFO - Calculating EMA with periods [9, 14, 20, 40, 100, 200] using price source: conditional1...
# 2025-08-07 03:55:46,262 - INFO - EMA_9 calculation completed
# 2025-08-07 03:55:46,272 - INFO - EMA_14 calculation completed
# 2025-08-07 03:55:46,282 - INFO - EMA_20 calculation completed
# 2025-08-07 03:55:46,292 - INFO - EMA_40 calculation completed
# 2025-08-07 03:55:46,301 - INFO - EMA_100 calculation completed
# 2025-08-07 03:55:46,311 - INFO - EMA_200 calculation completed
# 2025-08-07 03:55:46,312 - INFO - Calculating RMA with periods [14, 20] using price source: conditional1...
# 2025-08-07 03:55:46,322 - INFO - RMA_14 calculation completed
# 2025-08-07 03:55:46,332 - INFO - RMA_20 calculation completed
# 2025-08-07 03:55:46,333 - INFO - Calculating SMMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:56:31,933 - INFO - SMMA_20 calculation completed
# 2025-08-07 03:57:16,383 - INFO - SMMA_50 calculation completed
# 2025-08-07 03:57:16,385 - INFO - Calculating TEMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:16,422 - INFO - TEMA_20 calculation completed
# 2025-08-07 03:57:16,460 - INFO - TEMA_50 calculation completed
# 2025-08-07 03:57:16,461 - INFO - Calculating THMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:16,733 - INFO - THMA_20 calculation completed
# 2025-08-07 03:57:17,259 - INFO - THMA_50 calculation completed
# 2025-08-07 03:57:17,261 - INFO - Calculating VWMA with periods [9, 14, 20, 50, 100] using price source: conditional1...
# 2025-08-07 03:57:17,293 - INFO - VWMA_9 calculation completed
# 2025-08-07 03:57:17,324 - INFO - VWMA_14 calculation completed
# 2025-08-07 03:57:17,357 - INFO - VWMA_20 calculation completed
# 2025-08-07 03:57:17,393 - INFO - VWMA_50 calculation completed
# 2025-08-07 03:57:17,433 - INFO - VWMA_100 calculation completed
# 2025-08-07 03:57:17,433 - INFO - Calculating WMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:17,544 - INFO - WMA_20 calculation completed
# 2025-08-07 03:57:17,680 - INFO - WMA_50 calculation completed
# 2025-08-07 03:57:17,681 - INFO - Calculating ZEMA with periods [9, 14, 20, 26, 52] using price source: conditional1...
# 2025-08-07 03:57:17,722 - INFO - ZEMA_9 calculation completed
# 2025-08-07 03:57:17,737 - INFO - ZEMA_14 calculation completed
# 2025-08-07 03:57:17,748 - INFO - ZEMA_20 calculation completed
# 2025-08-07 03:57:17,761 - INFO - ZEMA_26 calculation completed
# 2025-08-07 03:57:17,775 - INFO - ZEMA_52 calculation completed
# 2025-08-07 03:57:17,776 - INFO - Calculating EVWMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:17,940 - INFO - EVWMA_20 calculation completed
# 2025-08-07 03:57:18,105 - INFO - EVWMA_50 calculation completed
# 2025-08-07 03:57:18,106 - INFO - Calculating T3 with periods [3, 5, 20] using price source: conditional1...
# 2025-08-07 03:57:18,163 - INFO - T3_3 calculation completed
# 2025-08-07 03:57:18,223 - INFO - T3_5 calculation completed
# 2025-08-07 03:57:18,281 - INFO - T3_20 calculation completed
# 2025-08-07 03:57:18,282 - INFO - Calculating WWMA with periods [14, 20] using price source: conditional1...
# 2025-08-07 03:57:18,293 - INFO - WWMA_14 calculation completed
# 2025-08-07 03:57:18,304 - INFO - WWMA_20 calculation completed
# 2025-08-07 03:57:18,305 - INFO - Calculating CMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:18,507 - INFO - CMA_20 calculation completed
# 2025-08-07 03:57:18,808 - INFO - CMA_50 calculation completed
# 2025-08-07 03:57:18,808 - INFO - Calculating GMMA with periods [20, 50] using price source: conditional1...
# INFO:2025-08-07 03:57:19,109:jax._src.xla_bridge:749: Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# 2025-08-07 03:57:19,109 - INFO - Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# 2025-08-07 03:57:20,417 - INFO - GMMA_20 calculation completed
# 2025-08-07 03:57:20,709 - INFO - GMMA_50 calculation completed
# 2025-08-07 03:57:20,710 - INFO - Calculating EALF with periods [9, 12, 20, 26, 50] using price source: conditional1...
# 2025-08-07 03:57:20,954 - INFO - EALF_9 calculation completed
# 2025-08-07 03:57:21,031 - INFO - EALF_12 calculation completed
# 2025-08-07 03:57:21,147 - INFO - EALF_20 calculation completed
# 2025-08-07 03:57:21,227 - INFO - EALF_26 calculation completed
# 2025-08-07 03:57:21,302 - INFO - EALF_50 calculation completed
# 2025-08-07 03:57:21,304 - INFO - Calculating ELF with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:21,381 - INFO - ELF_20 calculation completed
# 2025-08-07 03:57:21,457 - INFO - ELF_50 calculation completed
# 2025-08-07 03:57:21,458 - INFO - Calculating SWMA with periods [20, 50] using price source: conditional1...
# 2025-08-07 03:57:21,638 - INFO - SWMA_20 calculation completed
# 2025-08-07 03:57:21,807 - INFO - SWMA_50 calculation completed
# 2025-08-07 03:57:21,809 - INFO - Technical indicator calculations completed. 114 indicators calculated.
# 2025-08-07 03:57:21,815 - INFO - Combining original data with technical indicators...
# 2025-08-07 03:57:22,351 - INFO - Adding cyclic time features
# Adding time features:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-07 03:57:22,359 - INFO - Adding adaptive time features for LSTM modeling...
# 2025-08-07 03:57:22,968 - INFO - Auto-detected timeframe: 1m
# 2025-08-07 03:57:24,356 - INFO - Added 14 time features for 1m timeframe
# 2025-08-07 03:57:25,352 - INFO - Reset index to create 'timestamp' column
# 2025-08-07 03:57:25,353 - INFO - Saving processed data to F:/CMAPSS/TFT/prepared_data//SOL_1m_2024.csv...
# Saving results:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-07 03:59:29,910 - INFO - ==== Processing completed in 264.65 seconds ====
# 2025-08-07 03:59:29,910 - INFO - Final dataset: 840876 rows × 134 columns
# 2025-08-07 03:59:29,911 - INFO - Results saved to: F:/CMAPSS/TFT/prepared_data//SOL_1m_2024.csv
